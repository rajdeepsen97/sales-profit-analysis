# %%
import pandas as pd

# %%
# WE WILL DISPLAY THE CSV FILE WITH FIRST 5 ROWS

# %%
df = pd.read_csv("Superstore.csv", encoding='latin1')
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# WE WILL DISPLAY ALL THE COULUMN NAMES

# %%
print(df.columns)
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
# Step 1: Clean Columns (SOMETIMES COULUMNS NAMES HAVE EXTRA SPACES, WE WILL REMOVE THEM BY :-)

# %%
df.columns = df.columns.str.strip()                   #------------> Avoid hidden space errors like 'Profit ' vs 'Profit'

# %%
# Step 2: Profit Analysis (VERY IMPORTANT)

# %%
profit_by_category = df.groupby('Category')['Profit'].sum().sort_values(ascending=False)
print(profit_by_category)
# Out:
# Category
# Technology         145454.9481
# Office Supplies    122490.8008
# Furniture           18451.2728
# Name: Profit, dtype: float64

# %%
# Step 3: Profit by Region

# %%
profit_by_region = df.groupby('Region')['Profit'].sum().sort_values(ascending=False)
print(profit_by_region)
# Out:
# Region
# West       108418.4489
# East        91522.7800
# South       46749.4303
# Central     39706.3625
# Name: Profit, dtype: float64

# %%
# Step 4: Loss-making Areas (THIS IMPRESSES INTERVIEWERS)

# %%
df[df['Profit'] < 0].groupby('Category')['Profit'].sum()
# Out:
# Category
# Furniture         -60936.1090
# Office Supplies   -56615.2585
# Technology        -38579.9182
# Name: Profit, dtype: float64

# %%
# Step 5: Visualization (matplotlib)

# %%
import matplotlib.pyplot as plt

profit_by_category.plot(kind='bar')
plt.title("Profit by Category")
plt.show()

# %%
# Step 6: THINK LIKE ANALYST (MOST IMPORTANT)

# 1. Which category has highest profit?
profit_by_category = df.groupby('Category')['Profit'].sum().sort_values(ascending=False)
print(profit_by_category)


# 2. Which region is most profitable?
profit_by_region = df.groupby('Region')['Profit'].sum().sort_values(ascending=False)
print(profit_by_region)



# 3. Any category showing loss?
loss_category = df[df['Profit'] < 0].groupby('Category')['Profit'].sum()
print(loss_category)
# Out:
# Category
# Technology         145454.9481
# Office Supplies    122490.8008
# Furniture           18451.2728
# Name: Profit, dtype: float64
# Region
# West       108418.4489
# East        91522.7800
# South       46749.4303
# Central     39706.3625
# Name: Profit, dtype: float64
# Category
# Furniture         -60936.1090
# Office Supplies   -56615.2585
# Technology        -38579.9182
# Name: Profit, dtype: float64

# %%
#-------------------1.Top Profit Category
# Technology 
# (145,454 — highest)



#-----------------2.Most Profitable Region
# West 
# (108,418 — highest)



#--------3.Loss Analysis (important nuance)
# Furniture         -60936
# Office Supplies   -56615
# Technology        -38579

# %%
# Final Business Insights (USE THIS)


# Technology category generates the highest overall profit
# West region is the most profitable region
# All categories experience losses, but Furniture has the highest loss, indicating potential issues like heavy discounting or high costs
